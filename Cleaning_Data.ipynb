# %% [markdown]
# <a href="https://colab.research.google.com/github/Calobite/ml-model-development/blob/main/Cleaning_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as no
import pandas as pd

# %%
receipes = pd.read_csv("https://raw.githubusercontent.com/RachmasariAR/Capstone_Project/refs/heads/main/recipes.csv")
calories = pd.read_csv("https://raw.githubusercontent.com/RachmasariAR/Capstone_Project/refs/heads/main/food_calories.csv")

# %%
receipes
# Out:
#       Unnamed: 0                        recipe_name prep_time cook_time  \
# 0              0           Apple-Cranberry Crostada       NaN       NaN
# 1              1          Apple Pie by Grandma Ople   30 mins     1 hrs
# 2              2        Sarah's Homemade Applesauce   10 mins   15 mins
# 3              3                        Apple Crisp   30 mins   45 mins
# 4              4                  Apple Pie Filling   20 mins   20 mins
# ...          ...                                ...       ...       ...
# 1085        1085                     Date-Nut Balls   15 mins   10 mins
# 1086        1086                       Jamaica Cake       NaN       NaN
# 1087        1087                     Best Hot Sauce   10 mins   20 mins
# 1088        1088               Moist Date Nut Bread   15 mins   50 mins
# 1089        1089  Chef John's Chocolate Energy Bars   15 mins       NaN
#
#          total_time  servings              yield  \
# 0               NaN         8  6 to 8 - servings
# ...

# %%
calories
# Out:
#            Food              Serving Calories
# 0     Artichoke  1 artichoke (128 g)   60 cal
# 1       Arugula         1 leaf (2 g)    1 cal
# 2     Asparagus       1 spear (12 g)    2 cal
# 3     Aubergine  1 aubergine (458 g)  115 cal
# 4      Beetroot        1 beet (82 g)   35 cal
# ...         ...                  ...      ...
# 2557    Sausage       3 slice (60 g)  377 cal
# 2558       Plum        2 tsp (380 g)   53 cal
# 2559   Soy Milk        3 tsp (381 g)   43 cal
# 2560     Carrot         1 oz (212 g)   24 cal
# 2561      Pasta         1 oz (168 g)  344 cal
#
# [2562 rows x 3 columns]

# %%
receipes.duplicated().sum()
# Out:
# 0

# %%
calories.duplicated().sum()
# Out:
# 14

# %%
calories = calories.drop_duplicates()
calories.duplicated().sum()
# Out:
# 0

# %%
calories.isnull().sum()
# Out:
# Food        0
# Serving     0
# Calories    0
# dtype: int64

# %%
receipes.isnull().sum()
# Out:
# Unnamed: 0        0
# recipe_name       0
# prep_time        51
# cook_time       308
# total_time       45
# servings          0
# yield           211
# ingredients       0
# directions        0
# rating            0
# url               0
# cuisine_path      0
# nutrition         0
# timing            0
# img_src           0
# dtype: int64

# %%
receipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090 entries, 0 to 1089
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1090 non-null   int64
#  1   recipe_name   1090 non-null   object
#  2   prep_time     1039 non-null   object
#  3   cook_time     782 non-null    object
#  4   total_time    1045 non-null   object
#  5   servings      1090 non-null   int64
#  6   yield         879 non-null    object
#  7   ingredients   1090 non-null   object
#  8   directions    1090 non-null   object
#  9   rating        1090 non-null   float64
#  10  url           1090 non-null   object
#  11  cuisine_path  1090 non-null   object
#  12  nutrition     1090 non-null   object
#  13  timing        1090 non-null   object
#  14  img_src       1090 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 127.9+ KB

# %%
calories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2548 entries, 0 to 2561
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Food      2548 non-null   object
#  1   Serving   2548 non-null   object
#  2   Calories  2548 non-null   object
# dtypes: object(3)
# memory usage: 79.6+ KB

# %%
not receipes["recipe_name"].is_unique
# Out:
# True

# %%
receipes.duplicated().sum()
# Out:
# 0

# %%
receipes["recipe_name"].duplicated().sum()
# Out:
# 129

# %%
receipes.drop_duplicates(subset="recipe_name", inplace=True)

# %%
receipes["recipe_name"].duplicated().sum()
# Out:
# 0

# %%
filtered_df = receipes.loc[receipes['ingredients'].str.contains('chicken')]
filtered_df
# Out:
#      Unnamed: 0                                        recipe_name prep_time  \
# 13           13                                  Mulligatawny Soup   20 mins
# 148         148             Pork Tenderloin with Apples and Onions   15 mins
# 177         177                               Cherry Chicken Salad   15 mins
# 200         200                                     Cherry Chicken   15 mins
# 213         213  Fresh Figs and Chicken Thighs in Shallot-Balsa...   15 mins
# 224         224            Chicken Tenders with Balsamic-Fig Sauce   15 mins
# 237         237  Prosciutto-Wrapped Chicken with Figs and Goat ...   20 mins
# 300         300         Cornish Game Hens with Garlic and Rosemary   20 mins
# 302         302                 Greek-Style Lemon Roasted Potatoes   15 mins
# 304         304                    Easy Lemon-Pepper Chicken Wings   10 mins
# 305         305                           Famous Chicken Française   20 mins
# ...

# %%
receipes.to_csv("receipes_nodup.csv", index=True)
